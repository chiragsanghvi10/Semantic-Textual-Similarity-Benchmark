# %% [markdown]
# # Importing necessary packages

# %%
import pandas as pd
import os
import numpy as np
import requests
import json
from sklearn.preprocessing import MinMaxScaler
from scipy import stats
from scipy.stats import pearsonr

# %%
pwd = os.getcwd()
pwd
# Out:
# '/home/chirag/git/ai/Benchmark/Sentence Similarity V.0'

# %% [markdown]
# # Reading the data set

# %%
data = open("./datasets/STS-SemEval/2012/MSRpar.train.tsv")
data = data.readlines()
data
# Out:
# ['4.000\tBut other sources close to the sale said Vivendi was keeping the door open to further bids and hoped to see bidders interested in individual assets team up.\tBut other sources close to the sale said Vivendi was keeping the door open for further bids in the next day or two.\n',
#  "3.750\tMicron has declared its first quarterly profit for three years.\tMicron's numbers also marked the first quarterly profit in three years for the DRAM manufacturer.\n",
#  "2.800\tThe fines are part of failed Republican efforts to force or entice the Democrats to return.\tPerry said he backs the Senate's efforts, including the fines, to force the Democrats to return.\n",
#  "3.400\tThe American Anglican Council, which represents Episcopalian conservatives, said it will seek authorization to create a separate group.\tThe American Anglican Council, which represents Episcopalian conservatives, said it will seek authorization to create a separate province in North America because of last week's actions.\n",
#  '2.400\tThe tech-loaded Nasdaq composite rose 20.96 points to 1595.91, ending at its highest level for 12 months.\tThe technology-laced Nasdaq Composite Index <.IXIC> climbed 19.11 points, or 1.2 percent, to 1,615.02.\n',
#  '1.333\tAmgen shares gained 93 cents, or 1.45 percent, to $65.05 in afternoon trading on Nasdaq.\tShares of Allergan were up 14 cents at $78.40 in late trading on the New York Stock Exchange.\n',
#  '4.600\tU.S. prosecutors have arrested more than 130 individuals and have seized more than $17 million in a continuing crackdown on Internet fraud and abuse.\tMore than 130 people have been arrested and $17 million worth of property seized in an Internet fraud sweep announced Friday by three U.S. government agencies.\n',
#  '3.800\tChavez said investigators feel confident they\'ve got "at least one of the fires resolved in that regard."\tAlbuquerque Mayor Martin Chavez said investigators felt confident that with the arrests they had "at least one of the fires resolved."\n',
#  '4.200\tAuthorities said the scientist properly quarantined himself at home after he developed SARS symptoms Dec. 10.\tThe scientist also quarantined himself at home as soon as he developed SARS symptoms, officials said.\n',
#  '2.600\tThe support will come as a free software upgrade called WebVPN for current customers that have support contracts.\tThe upgrade will be available as a free download for current customers with SmarNet support in January 2004.\n',
#  '4.400\tThe man accused of using fake grenades to commandeer a Cuban plane that landed in Key West in April was sentenced Friday to 20 years in prison.\tA Cuban architect was sentenced to 20 years in prison Friday for using two fake grenades to hijack a passenger plane from Cuba to Florida in April.\n',
#  '4.200\tJim Williams, director of the US-VISIT project, said that by the middle of November, many arriving passengers in Atlanta will be fingerprinted and photographed.\tJim Williams, director of the US-VISIT project, said that by the middle of November, inspectors will be fingerprinting and photographing many foreign passengers arriving in Atlanta.\n',
#  '5.000\tThe hearing occurred a day after the Pentagon for the first time singled out an officer, Dallager, for not addressing the scandal.\tThe hearing came one day after the Pentagon for the first time singled out an officer - Dallager - for failing to address the scandal.\n',
#  "5.000\tThe Episcopal Church ''is alienating itself from the Anglican Communion,'' said the Very Rev. Peter Karanja, provost of the All Saints Cathedral, in Nairobi.\tIn Nairobi, the provost of All Saints Cathedral, the Very Reverend Peter Karanja, said the US Episcopal Church was alienating itself from the Anglican Communion.\n",
#  '5.000\tCounties with population declines will be Vermillion, Posey and Madison.\tVermillion, Posey and Madison County populations will decline.\n',
#  '3.400\tSwartz, indicted in February, had argued that New Hampshire was the wrong place to charge him.\tSwartz had sought to have the charges dismissed, saying New Hampshire was the wrong place to charge him.\n',
#  '5.000\tThe last time the survey was conducted, in 1995, those numbers matched.\tIn 1995, the last survey, those numbers were equal.\n',
#  '4.000\tHigher courts have ruled that the tablets broke the constitutional separation of church and state.\tThe federal courts have ruled that the monument violates the constitutional ban against state-established religion.\n',
#  '3.200\tThey were at Raffles Hospital over the weekend for further evaluation.\tThey underwent more tests over the weekend, and are now warded at Raffles Hospital.\n',
#  '5.000\tWhen the bomb exploded at the Casa de España, customers were eating dinner and playing bingo.\tAt the Casa de Espaa, customers were eating dinner and playing bingo when a bomb went off.\n',
#  "4.400\tPlofsky said the commission won't investigate because the three-year statute of limitations has expired.\tThe panel will not begin a formal investigation because the statute of limitations has expired, Plofsky said.\n",
#  "3.600\tIn two weeks, he'll probably send out Peace Rules in the Preakness.\tFrankel said Peace Rules will run in the Preakness Stakes on May 17.\n",
#  '3.600\tIf convicted of the spying charges, he could face the death penalty.\tThe charges of espionage and aiding the enemy can carry the death penalty.\n',
#  "0.800\tThe technology-laced Nasdaq Composite Index was up 7.60 points, or 0.46 percent, at 1,653.62.\tThe broader Standard & Poor's 500 Index <.SPX> shed 2.38 points, or 0.24 percent, at 995.10.\n",
#  '1.400\tHilsenrath and Klarman each were indicted on three counts of securities fraud.\tKlarman was charged with 16 counts of wire fraud.\n',
#  '3.200\tEntrenched interests are positioning themselves to control the network\'s chokepoints and they are lobbying the FCC to aid and abet them.\tIt may be dying because entrenched interests are positioning themselves to control the Internet\'s choke-points and they are lobbying the FCC to aid and abet them."\n',
#  '3.800\tBut church members and observers say they expect that the decision could be problematic for many Episcopalians.\tBut church members and observers say they anticipate that the decision here could pose doctrinal problems for some Episcopalians who believe the Bible prohibits homosexuality.\n',
#  "4.200\tSquyres is principal investigator for the Athena payload - a collection of science instruments carted by each rover.\tSteve Squyres, a Cornell University scientist, is principal investigator for the missions' science instruments.\n",
#  '3.000\tThe military said it had killed 12 rebels and captured nine in the campaign so far, for the loss of six soldiers wounded.\tThe military said it had killed 16 rebels and captured nine in the campaign so far, with one soldier killed and six wounded.\n',
#  "3.600\tThe new sensor -- dubbed CANARY for ''cellular analysis and notification of antigen risks and yields'' -- hijacks this natural process with two important changes.\tThe team has named the sensor Canary, for cellular analysis and notification of antigen risks and yields.\n",
#  '3.000\tExpress Scripts ESRX.O shares fell 3.6 percent to close at $66.89 on the Nasdaq.\tShares of Express Scripts ESRX.O fell about 4 percent to $66.73 on the Nasdaq in late morning trade.\n',
#  "3.000\tOne, Fort Carson-based Sgt. Ernest Bucklew, 33, had been on his way home to attend his mother's funeral in Pennsylvania.\tSgt. Ernest Bucklew, 33, was coming home from Iraq to bury his mother in Pennsylvania.\n",
#  '3.000\tPolice launched an international hunt for Shevaun Pennington after she ran away with 31-year-old Toby Studabaker Saturday.\tShevaun Pennington disappeared on Saturday morning after arranging to meet 31-year-old Toby Studabaker.\n',
#  '4.800\tLawyers and others familiar with the federal investigation say it remains focused on Campbell, though prosecutors declined to discuss the probe.\tWhile federal prosecutors refuse to discuss the investigation, lawyers and others familiar with it say it remains focused on Campbell.\n',
#  '2.500\tThe Dow Jones industrial average .DJI was off 58.69 points, or 0.64 percent, at 9,137.86.\tThe blue-chip Dow Jones industrial average .DJI fell 86.56 points, or 0.94 percent, to 9,109.99, after giving up more than 1 percent earlier.\n',
#  '2.250\tPeace Rules defeated Funny Cide in the Louisiana Derby.\tBut neither he nor Peace Rules could keep Funny Cide from drawing away.\n',
#  '3.500\tWaksal has pleaded guilty to securities fraud and is to be sentenced next week.\tWaksal pleaded guilty to insider trading charges last year, and he is scheduled to be sentenced June 10.\n',
#  '3.500\tHe allowed two runs in seven innings and struck out six.\tZambrano pitched seven innings and allowed two runs on five hits and four walks.\n',
#  '3.000\tStill, he said, "I\'m absolutely confident we\'re going to have a bill."\t"I\'m absolutely confident we\'re going to have a bill," Frist, R-Tenn., said Thursday.\n',
#  '3.000\tBoeing said the final agreement is expected to be signed during the next few weeks.\tThe Korean Air deal is expected to be finalized "in the next several weeks," Boeing spokesman Bob Saling said.\n',
#  '3.667\tShares in EDS closed on Thursday at $18.51, a gain of 6 cents.\tShares of EDS closed Thursday at $18.51, up 6 cents on the New York Stock Exchange.\n',
#  '1.667\tNationally, the federal Centers for Disease Control and Prevention recorded 4,156 cases of West Nile, including 284 deaths.\tThere were 293 human cases of West Nile in Indiana in 2002, including 11 deaths statewide.\n',
#  "3.600\tA divided Supreme Court ruled Monday that Congress can force the nation's public libraries to equip computers with anti-pornography filters.\tThe Supreme Court said Monday the government can require public libraries to equip computers with anti-pornography filters, rejecting librarians' complaints that the law amounts to censorship.\n",
#  "3.800\tThe weakness exists in the way that VBA looks at the properties of documents passed to it when the document is opened by a host application.\tThe vulnerability exists in the way Microsoft's Visual Basic for Applications checks document properties passed to it when a document is opened.\n",
#  '3.400\tOf 24 million phoned-in votes, 50.28 percent were for Studdard, putting him 130,000 votes ahead of Aiken.\tOf the 24 million phone votes cast, Studdard was only 130,000 votes ahead of Aiken.\n',
#  '3.400\tConsumers still would have to get a descrambling security card from their cable operator to plug into the set.\tTo watch pay television, consumers would insert into the set a security card provided by their cable service.\n',
#  '3.800\tHowever, we have decided to opt for the European consortium\'s engine as the best overall solution and due to the substantial price efforts made".\tHowever, we have decided to opt for the European consortium\'s engine as the best overall solution."\n',
#  "2.800\tThe Food and Drug Administration rejected ImClone's 2001 application to sell Erbitux, citing shoddy research.\tThe U.S. Food and Drug Administration rejected ImClone's original application in December 2001, saying the trial had been sloppily conducted.\n",
#  '3.750\tCritics say the law violates civil liberties, something House Judiciary Committee Chairman James Sensenbrenner, R-Wis., says he is sensitive to.\tHouse Judiciary Committee Chairman James Sensenbrenner, R-Wis., says he is sensitive to civil liberties complaints.\n',
#  '4.400\tThe Dodgers won their sixth consecutive game their longest win streak since 2001 as they edged Colorado, 3-2, Wednesday in front of a crowd of 25,332 at Dodger Stadium.\tThe Dodgers won their sixth consecutive game and seventh in their last nine as they beat Colorado 3-2 on Wednesday in front of a crowd of 25,332 at Dodger Stadium.\n',
#  '3.750\tSo far, they have searched Pennsylvania, Ohio, Michigan, Illinois and Indiana, authorities in those state said.\tSo far, authorities also have searched areas in Pennsylvania, Ohio, Indiana, and Michigan.\n',
#  '2.750\tThe 30-year bond US30YT=RR firmed 31/32, taking its yield to 4.16 percent -- another record low -- from 4.22 percent.\tThe 30-year bond <US30YT=RR> firmed 24/32, taking its yield to 4.18 percent, after hitting another record low of 4.16 percent.\n',
#  "3.750\tOn Thursday, a Washington Post article argued that a 50 basis point cut from the Fed was more likely, contrary to the Wall Street Journal's line.\tOn Thursday, a Post article argued that a 50 basis point cut from the Fed was more likely.\n",
#  '2.250\tMr. Heatley, who suffered a broken jaw and torn knee ligaments, faces several charges.\tHeatley underwent surgery Saturday for a broken jaw and an MRI found two torn ligaments in his right knee.\n',
#  '3.800\tLay had argued that handing over the documents would be a violation of his Fifth Amendment rights against self-incrimination.\tLay had refused to turn over the papers, asserting his Fifth Amendment right against self-incrimination.\n',
#  '3.200\tStrayhorn said it was the first time in Texas history a comptroller had not certified the appropriations act.\tIn a news release Thursday, Strayhorn said this was the first time a comptroller rejected a budget.\n',
#  '3.800\tExcluding the charges, analysts, on average, expected a loss of 11 cents a share.\tAnalysts polled by Thomson Financial First Call had been expected to see a loss of about 11 cents a share from continuing operations.\n',
#  '4.800\tSecurity experts are warning that a new mass-mailing worm is spreading widely across the Internet, sometimes posing as e-mail from the Microsoft founder.\tA new worm has been spreading rapidly across the Internet, sometimes pretending to be an e-mail from Microsoft Chairman Bill Gates, antivirus vendors said Monday.\n',
#  '4.000\tMr Sahel said police had identified the bodies of seven of the 14-strong cell believed to have carried out the five almost simultaneous attacks on Saturday.\tHe said police had identified the bodies of seven of the 14 bombers who launched five almost simultaneous raids Friday night.\n',
#  '1.400\tOnly New Jersey now bans holders of learners permits or intermediate licenses from using cell phones, pagers or other wireless devices while driving.\tIn addition, the NTSB also recommended to NHTSA that state legislation be enacted to prohibit holders of learners permits and intermediate licenses from using mobile phones while driving.\n',
#  '4.200\tThe University of Michigan released today a new admissions policy after the U.S. Supreme Court struck down in June the way it previously admitted undergraduates.\tThe University of Michigan plans to release a new undergraduate admissions policy Thursday after its acceptance requirements were rejected by the U.S. Supreme Court in June.\n',
#  '1.800\tThe audiotape aired last week by the Arab Al-Jazeera television network appears to be an effort to incite attacks.\tAn audiotape aired last week by the Arab al-Jazeera television network may be the strongest evidence yet that Saddam survived the war.\n',
#  "4.200\tFormer company chief financial officer Franklyn M. Bergonzi pleaded guilty to one count of conspiracy on June 5 and agreed to cooperate with prosecutors.\tLast week, former chief financial officer Franklyn Bergonzi pleaded guilty to one count of conspiracy and agreed to cooperate with the government's investigation.\n",
#  "2.000\tThe company didn't detail the costs of the replacement and repairs.\tBut company officials expect the costs of the replacement work to run into the millions of dollars.\n",
#  '2.600\tDean told reporters traveling on his 10-city "Sleepless Summer" tour that he considered campaigning in Texas a challenge.\tToday, Dean ends his four-day, 10-city "Sleepless Summer" tour in Chicago and New York.\n',
#  '3.250\t"I felt that if I disagreed with Rosie too much I would lose my job," she said.\tCavender did say: "I felt that if I disagreed with Rosie too much I would lose my job."\n',
#  "5.000\tThe device plays Internet radio streams and comes with a 30-day trial of RealNetworks' Rhapsody music service.\tThe product also streams Internet radio and comes with a 30-day free trial for RealNetworks' Rhapsody digital music subscription service.\n",
#  '3.000\tThe dollar fell as low as $1.1624 per euro from $1.1486 on Friday, and traded at $1.1594 at 10:15 a.m. in London.\tThe dollar dropped to $1.1564 per euro at 7:30 a.m. in London from $1.1486 on Friday.\n',
#  '3.750\tThe American decision provoked an angry reaction from the European Commission, which described the move as "legally unwarranted, economically unfounded and politically unhelpful".\tThe European Commission, the EU\'s powerful executive body, described the move as "legally unwarranted, economically unfounded and politically unhelpful."\n',
#  "4.250\tMs. Cripps-Prawak left last Friday, two days after the department introduced a plan to distribute medical marijuana through doctors' offices.\tThe director of the Office of Medical Access, Cindy Cripps-Prawak, left her job after the department introduced a plan to distribute marijuana through doctors' offices.\n",
#  "4.750\tDuring 2001 and 2002, Morgenthau said, wire transfers from just four of Beacon Hill's 40 accounts totaled more than $3.2 billion.\tWire transfers from four of the 40 accounts open at Beacon Hill totaled more than $3.2 billion from 2001 to 2002, Morgenthau said.\n",
#  '3.250\tLast year, he made an unsuccessful bid for the Democratic nomination for governor.\tHe ran last year for the Democratic nomination for Texas governor, but lost the primary to multimillionaire Tony Sanchez.\n',
#  "3.750\tThe nation's largest retailer has told its 100 top suppliers they have to start using electronic tags on all pallets of goods by Jan. 25, 2005.\tWal-Mart has told its top 100 suppliers that they'll need to have radio-frequency ID systems in place for tracking pallets of goods through the supply chain by Jan. 25, 2005.\n",
#  "3.250\tHe was taken to a hospital for precautionary X-rays on his neck.\tHarvey was taken to St. Luke's Hospital for precautionary neck X-rays, which came back negative.\n",
#  '3.800\tDuring the hearing, Morales expressed "sincere regrets and remorse" for his actions.\tMorales, who pleaded guilty in July, expressed "sincere regret and remorse" for his crimes.\n',
#  "5.000\tThe bill says that a woman who undergoes such an abortion couldn't be prosecuted.\tA woman who underwent such an abortion could not be prosecuted under the bill.\n",
#  '3.600\tU.S. District Judge Edmund Sargus ruled that the Akron-based company should have determined that changes at one of its plants would increase overall pollution emissions.\tFirstEnergy Corp. should have determined that modernizing one of its plants would increase overall pollution emissions, U.S. District Judge Edmund Sargus ruled Thursday.\n',
#  '3.800\tSite Finder has been visited 65 million times since its introduction, Galvin said.\tThrough Sunday, Sept. 21, Site Finder has been visited over 65 million times by Internet users.\n',
#  '2.000\tThere are 103 Democrats in the Assembly and 47 Republicans.\tDemocrats dominate the Assembly while Republicans control the Senate.\n',
#  '3.400\tMr Pollard said: "This is a terrible personal tragedy and a shocking blow for James\'s family.\tNick Pollard, the head of Sky News said: "This is a shocking blow for James\'s family.\n',
#  '4.200\t"I came basically to Washington to establish relationships and to make sure that we are getting more federal money to California," Schwarzenegger said after meeting with congressional Republicans.\t"I came to Washington basically to establish relationships and make sure we are getting more federal money," Schwarzenegger said after one meeting.\n',
#  '3.400\tThe latest snapshot of the labor markets was slightly better than economists were expecting; they were forecasting claims to fall no lower than 410,000 for last week.\tDespite problems in the job market, the latest snapshot of the labor markets was slightly better than economists were expecting.\n',
#  '3.000\t"They were tossed around like feathers," Gordon said.\t"The concrete barriers (between lanes) were being tossed around like feathers."\n',
#  '3.000\tChante Jawan Mallard, 27, went on trial Monday, charged with first-degree murder.\tChante Jawaon Mallard, 27, is charged with murder and tampering with evidence.\n',
#  '3.250\t"IT is the only vehicle on which established economies will be able to compete," Barrett said.\t"IT is the only vehicle on which established economies will be able to compete" with fast-growing economies such as China and India, Barrett said.\n',
#  '2.750\tLinda Saunders pleaded guilty in federal court to six charges, including extortion, money laundering and conspiracy.\tFormer Phipps aides Linda Saunders and Bobby McLamb have both pleaded guilty to federal charges including extortion.\n',
#  '2.600\tVivendi shares closed 3.8 percent up in Paris at 15.78 euros.\tVivendi shares were 0.3 percent up at 15.62 euros in Paris at 0841 GMT.\n',
#  '3.400\tMicrosoft has identified the freely distributed Linux software as one of the biggest threats to its sales.\tThe company has publicly identified Linux as one of its biggest competitive threats.\n',
#  '3.600\tAntonio Monteiro de Castro, 58, currently director of the group’s Latin America & Caribbean operations, will become chief operating officer from the same date.\tBAT also said Antonio Monteiro de Castro, director for Latin America and the Caribbean, would become chief operating officer on January 1, 2004.\n',
#  '3.600\t"Spin and manipulative public relations and propaganda are not the answer," it said.\tThe report added that "spin" and manipulative public relations "are not the answer," but that neither is avoiding the debate.\n',
#  '4.800\tAnother shooting linked to the spree occurred Nov. 11 at Hamilton Central Elementary in Obetz, about two miles from the freeway.\tThe latest shooting linked to the spree was a Nov. 11 shooting at Hamilton Township Elementary School in Obetz, about two miles from the freeway.\n',
#  "4.000\tOn Tuesday, the central bank left interest rates steady, as expected, but also declared that overall risks were weighted toward weakness and warned of deflation risks.\tThe central bank's policy board left rates steady for now, as widely expected, but surprised the market by declaring that overall risks were weighted toward weakness.\n",
#  '3.600\tThe new system costs between $1.1 million and $22 million, depending on configuration.\tThe system is priced from US$1.1 million to $22.4 million, depending on configuration.\n',
#  '3.400\tFighting erupted after four North Korean journalists confronted a dozen South Korean activists protesting human rights abuses in the North outside the main media centre.\tTrouble flared when at least four North Korean reporters rushed from the Taegu media centre to confront a dozen activists protesting against human rights abuses in the North.\n',
#  '2.400\tDusty had battled kidney cancer for more than a year.\tDusty had surgery for cancer in 2001 and had a kidney removed.\n',
#  '4.222\tAccording to SunnComm\'s Peter Jacobs, "MediaMax performs exactly as \'advertised\' to the companies who purchased it.\t"MediaMax performs EXACTLY as "advertised" to the companies who purchased it," Jacobs said in the statement.\n',
#  '3.000\tKadyrov was not injured, but four of his bodyguards were among those killed.\tBut Itar-Tass news agency said four of his bodyguards were among those killed by the bomb.\n',
#  '3.000\tThe router will be available in the first quarter of 2004 and will cost around $200, the company said.\tNetgear prices the WGT634U Super Wireless Media Router, which will be available in the first quarter of 2004, at under $200.\n',
#  '2.750\tThe commission estimates California lost $1.34 billion -- the most of any state -- to tax shelters in 2001.\tThe commission estimated California lost $937 million to corporate tax shelters in 2001.\n',
#  '4.000\tThe officials did not say whether U.S. forces crossed into Syrian territory and were vague about how the Syrian border guards became involved.\tU.S. officials did not say whether American forces, who were acting on intelligence, crossed into Syrian territory and were vague about how the Syrian guards were involved.\n',
#  '1.750\tVeriSign introduced its Site Finder service on Sept. 15.\tThe battle around VeriSign"s three-week-old Site Finder service rages on.\n',
#  "1.750\tOn Monday, as first reported by CNET News.com, the RIAA withdrew a DMCA notice to Penn State University's astronomy and astrophysics department.\tLast Thursday, the RIAA sent a stiff copyright warning to Penn State's department of astronomy and astrophysics.\n",
#  '4.500\tDruce is still being held at the prison and is now in isolation, she said.\tDruce last night was held in isolation at the same prison.\n',
#  '3.250\tThe first health-care worker in the country to die of SARS was a Filipina-Canadian who contracted the disease at North York General Hospital, the site of the second outbreak.\tEmile Laroza, 51, contracted SARS while working as a nurse at North York General Hospital, the epicentre of the second SARS outbreak.\n',
#  '5.000\tTheir leader, Abu Bakr al-Azdi, turned himself in in June; his deputy was killed in a recent shootout with Saudi forces.\tTheir leader, Abu Bakr al-Azdi, surrendered in June; his deputy was killed in a shoot-out with Saudi forces recently.\n',
#  "3.000\tAfter Freitas' opening statement, King County Superior Court Judge Charles Mertel recessed trial until after the Thanksgiving weekend.\tKing County Superior Court Judge Charles Mertel will then recess the trial until Monday.\n",
#  "2.800\tGoogle's investors include prominent VC firms Kleiner Perkins Caufield & Byers and Sequoia Capital, the paper noted.\tGoogle's early stage backers in include California-based Stanford University and VC firms Kleiner Perkins and Sequoia Capital.\n",
#  "2.667\tJuly 1st is the sixth anniversary of Hong Kong's return to Chinese rule.\tThe rally overshadowed ceremonies marking the sixth anniversary of Hong Kong's return to China on 1 July 1997.\n",
#  '4.000\tPalm Wednesday announced plans to acquire Handspring, a company started by Jeff Hawkins, regarded by many as the father of the Palm handheld.\tPalm said on Wednesday it plans to buy Handspring, a company created by renegade Palm co-founder Jeff Hawkins.\n',
#  '4.400\t"I\'m not going to be sponsoring it because it is not our proposal but I\'m not going to be negative about it".\t"I\'m not going to be sponsoring it because it\'s not our proposal, but I\'m not responding to it in a negative way," he said.\n',
#  '4.250\tThe government recently shelved peace talks with the MILF, being brokered by Malaysia, after a string of attacks, including three bombings, on Mindanao.\tThe government recently shelved peace talks being brokered by neighbouring Malaysia after a spate of attacks on Mindanao, including three deadly bombings, that it blamed on the MILF.\n',
#  '4.176\tThe company posted a profit of $54.3 million, or 22 cents per share, in the year-ago period.\tThat was up from the year-ago quarter, when the company earned $54.3 million, or 22 cents a share.\n',
#  '3.000\tJoining Boston on Monday were the Massachusetts communities of Watertown, Saugus and Framingham.\tAlong with Boston, Watertown, Saugus and Framingham also are going smoke-free Monday.\n',
#  '2.500\tHe was tracked to Atlanta where he was arrested on Tuesday night.\tHe was arrested in Atlanta, Georgia, on Monday night by police acting on a tip-off.\n',
#  '3.800\tISRAELI soldiers knocked down empty mobile homes and water towers in 10 tiny West Bank settlement outposts overnight as part of a US-backed Mideast peace plan.\tIsraeli soldiers began tearing down settlement outposts in the West Bank yesterday - an Israeli obligation under a new Mideast peace plan.\n',
#  '4.600\tThe union had not yet revealed which chain would be targeted.\tThe union said it would reveal later which chain would be targeted.\n',
#  '1.400\tGet it all out," says Howard Davidowitz, chairman of Davidowitz & Associates, a national retail consulting firm based in New York City.\tInnocent or not, "she\'s damaged goods," said Howard Davidowitz, chairman of Davidowitz & Associates, a national retail consulting firm in New York.\n',
#  '2.800\tThe updated products include Pylon Pro, Pylon Conduit, Pylon Anywhere, and Pylon Application Server.\tThe new products on the desktop side include the latest versions of Pylon Conduit and Pylon Pro.\n',
#  '2.800\tDixon was otherwise the class of the field at Pikes Peak International Raceway.\tScott Dixon eventually made winning the Honda Indy 225 look easy Sunday at Pikes Peak International Raceway.\n',
#  '4.200\tTurkish authorities have said all the suicide bombers were Turks.\tAnkara says all four suicide bombers were Turkish.\n',
#  '1.000\tIn April, it had forecast operating earnings in the range of 60 to 80 cents a share.\tKodak expects earnings of 5 cents to 25 cents a share in the quarter.\n',
#  '4.200\tFrom Florida to Alaska, thousands of revelers vowed to push for more legal rights, including same-sex marriages.\tThousands of revellers, celebrating the decision, vowed to push for more legal rights, including same-sex marriages.\n',
#  '2.750\tBy Sunday night, the fires had blackened 277,000 acres, hundreds of miles apart.\tMajor fires had burned 264,000 acres by early last night.\n',
#  '2.500\tOthers with such a status are Egypt, Israel, and Australia.\tNations like Israel and Australia already have such status.\n',
#  "3.500\tThe findings appear in Wednesday's Journal of the American Medical Association (news - web sites).\tThe results are to be published in Wednesday's issue of The Journal of the American Medical Association.\n",
#  '4.750\tAdditionally, the h2210’s cradle has room to charge a second battery.\tThe cradle for the h2200 has space for recharging a second battery.\n',
#  '3.000\tU.S. forces struck dozens of targets on Monday, killing six guerrillas and arresting 21 others, the military said.\tU.S. forces struck dozens of targets on Monday, killing six guerrillas and arresting 99 others during 1,729 patrols and 25 raids conducted over 24 hours.\n',
#  '3.500\tOne of the 14 Kurds pointed at the word "refugee" in an English/Turkish dictionary.\tOne man had brandished an English-Turkish dictionary and pointed to the word "refugee".\n',
#  '4.000\t"Close co-operation between law-enforcement agencies and intelligence services lie at the heart of the ongoing fight against terrorism," Mr Howard said.\tClose cooperation between regional law enforcement agencies and intelligence services was at the heart of the fight against terrorism, he said.\n',
#  '2.000\tIn 2006, the group says the market will rebound 29.6 percent to $21.3 billion in sales.\tIn 2006, Asia Pacific will report growth of 7.9 percent to $81.8 billion.\n',
#  "3.200\tCaptain Robert Ramsey of the US 1st Armoured Division said a truck had exploded outside the building about 11am, and that one of the compound's outer walls had collapsed.\tCaptain Robert Ramsey of US 1St Armored Division said a truck had exploded outside the building at around 11 am.\n",
#  '3.600\tThey came despite what BA called a "difficult quarter", which it said included unofficial industrial action at Heathrow.\tBA said the second quarter, which included unofficial industrial action at Heathrow, had been difficult.\n',
#  '3.800\tThis northern autumn US trainers will work with soldiers from four North African countries on patrolling and gathering intelligence.\tLater this year, the command will send trainers with soldiers from four North African nations on patrolling and intelligence gathering missions.\n',
#  '5.000\tThe Bush administration blames Hussein loyalists and foreign Muslim militants who have entered Iraq to fight U.S. troops for the wave of bombings and guerrilla attacks.\tThe Bush administration blames the wave of bombings and guerrilla attacks on Saddam loyalists and foreign Muslim militants who have entered Iraq to fight U.S. troops.\n',
#  '4.000\tIt later emerged that he had broken his right thigh and bones in his right wrist and elbow.\tTour doctors later confirmed that he had broken his right leg near the hip and also sustained wrist and elbow fractures.\n',
#  '3.000\tThe author is one of several defense experts expected to testify.\tSpitz is expected to testify later for the defense.\n',
#  '2.500\t"The figures are becoming catastrophic," said Dr. Patrick Pelloux, the president of the association of emergency room physicians.\tThis is unacceptable," said Patrick Pelloux, the president of France\'s Association of Emergency Doctors.\n',
#  '3.000\t"Whatever has happened to you by way of punishment is certainly more than enough," Covello told the 49-year-old, whose family, friends and supporters filled half the courtroom.\t"What has happened to you, sir, by way of punishment, is certainly more than enough," Covello said.\n',
#  '4.000\tThe mother also alleged in the lawsuit that she was sexually assaulted by one of the guards.\tThe mother also contended that she was sexually assaulted by one of the guards during the 1998 confrontation.\n',
#  '2.000\tThe two-year note US2YT=RR fell 5/32 in price, taking its yield to 1.23 percent from 1.16 percent late on Monday.\tThe benchmark 10-year note US10YT=RR lost 11/32 in price, taking its yield to 3.21 percent from 3.17 percent late on Monday.\n',
#  '3.000\tAs part of a restructuring Peregrine sold its Remedy help desk software unit last year to BMC Software Inc.\tPeregrine sold its Remedy business unit to BMC Software in November for $355 million.\n',
#  '2.625\tYes, from today Flash memory purchased from AMD or Fujitsu will be branded Spansion.\tSpansion Flash memory solutions are available worldwide from AMD and Fujitsu.\n',
#  "3.200\tThe world's two largest automakers said their U.S. sales declined more than predicted last month as a late summer sales frenzy caused more of an industry backlash than expected.\tDomestic sales at both GM and No. 2 Ford Motor Co. declined more than predicted as a late summer sales frenzy prompted a larger-than-expected industry backlash.\n",
#  '4.000\tA tropical storm rapidly developed in the Gulf of Mexico Sunday and was expected to hit somewhere along the Texas or Louisiana coasts by Monday night.\tA tropical storm rapidly developed in the Gulf of Mexico on Sunday and could have hurricane-force winds when it hits land somewhere along the Louisiana coast Monday night.\n',
#  '3.200\tThe pressure may well rise on Thursday, with national coverage of the final round planned by ESPN, the cable sports network.\tThe pressure will intensify today, with national coverage of the final round planned by ESPN and words that are even more difficult.\n',
#  '2.400\tPataki praised Abraham\'s decision, and LIPA Chairman Richard Kessel said the cable should be kept in operation permanently.\tLIPA Chairman Richard Kessel said that meant the cable could be used "as we see fit.\n',
#  '4.400\tPart of the accord was the implementation of a special health council that would monitor health spending and progress in reforming the health system.\tA key portion of the accord was the implementation of a special council to monitor health spending, set goals for the system and measure progress in reforming health care.\n',
#  '3.600\tDynes came to UC San Diego in 1991 after 22 years as a physicist with AT&T Bell Labs.\tDynes has been at UC San Diego since 1991 after spending 22 years with AT&T Bell Labs, where he worked on superconductors and other materials.\n',
#  '2.400\tShares in BA were down 1.5 percent at 168 pence by 1420 GMT, off a low of 164p, in a slightly stronger overall London market.\tShares in BA were down three percent at 165-1/4 pence by 0933 GMT, off a low of 164 pence, in a stronger market.\n',
#  '3.600\tThe Senate agreed Tuesday to lift a 10-year-old ban on the research and development of low-yield nuclear weapons.\tBoth the House and Senate bills would end the ban on research and development of low-yield nuclear weapons.\n',
#  "4.600\tMeningitis is an infection of the spinal cord fluid and the tissue around the brain.\tMeningitis is an infection of the fluid in a person's spinal cord and around the brain.\n",
#  '4.400\tThe companies, Chiron and Aventis Pasteur, together made about 80 million doses of the injected vaccine, which ordinarily would have been enough to meet U.S. demand.\tChiron and Aventis Pasteur together made about 80 million doses, ordinarily enough for U.S. demand, The Associated Press reported.\n',
#  '4.400\tMayor Joe T. Parker said late Thursday that the three workers were two men and a woman who were inside the building when the first blast occurred.\tThe missing workers, two men and a woman, were inside the building when the first blast occurred, Mayor Joe T. Parker said.\n',
#  '4.600\tLondon-based NCRI official Ali Safavi told Reuters: "We condemn this raid, which is in our view illegal and morally and politically unjustifiable."\t"We condemn this raid which is in our view illegal and morally and politically unjustifiable," London-based NCRI official Ali Safavi told Reuters by telephone.\n',
#  '4.400\tInvestigators uncovered a 4-inch bone fragment from beneath the concrete slab Thursday, but it turned out to be an animal bone, authorities said.\tInvestigators uncovered a 4-inch bone fragment Thursday night, but authorities said it was from an animal.\n',
#  '2.600\tJoining Stern and McEntee on stage was International Union of Painters and Allied Trades President James Williams.\tThe International Union of Painters and Allied Trades endorsed Mr Dean several weeks ago.\n',
#  '3.600\tIt exploded in his hands, but the former Italian prime minister was unhurt.\tThe letter bomb sent to Prodi exploded in his hands but he was unhurt.\n',
#  '4.200\tSome 95 million Americans -- half of all households -- invest in mutual funds.\tAbout half of all U.S. households have money in mutual funds.\n',
#  "3.200\tHalabi's military attorney, Air Force Maj. James Key, denied the charges, which could carry a death penalty.\tThe attorney representing al-Halabi, Air Force Maj. James Key III, denied the charges, according to The Associated Press.\n",
#  '2.000\tWaksal, in a letter to the court, said: "I tore my family apart.\tIn seeking leniency, Waksal apologized to the court, his employees and his family.\n',
#  '2.800\tSince early May, the city has received 1,400 reports of dead blue jays and crows, Jayroe said.\tSince early May, the city has received 1,400 reports, he said.\n',
#  '1.600\tBut Forest, the Freedom Organisation for the Right to Enjoy Smoking Tobacco, said: \'\'Mention the word prohibition and everyone knows what happened there.\tForest, the Freedom Organisation for the Right to Enjoy Smoking Tobacco, said it had greeted The Lancet\'s call with "amusement and disbelief\'".\n',
#  '3.400\tThe House has passed prescription-drug legislation in the last two sessions, but the Senate has failed to do so.\tThe House has passed bills the past two Congresses, but the Senate has not.\n',
#  "4.000\tOnce converted, BayStar will own an aggregate of approximately 2.95 million shares of SCO common stock or 17.5 percent of the company's outstanding shares.\tThe investment gives Larkspur, Calif.-based BayStar more than 2.9 million shares of SCO common stock, or 17.5 percent of the company's outstanding shares.\n",
#  '2.600\tThe elderly and those with weakened immune systems are also urged to protect against mosquito bites.\tBut for the elderly and those with weakened immune systems, it can be fatal.\n',
#  "2.800\tOPEC producers at a meeting on Wednesday are set to pressure independent oil exporters to contribute to the cartel's next supply cut to allow for the return of Iraqi oil.\tOPEC this week is set to pressure independent exporters to back the cartel's next supply cut to prevent the resumption of Iraqi exports undercutting oil prices.\n",
#  '3.000\tThe Winston-Salem, North Carolina company opened six stores during the quarter, bringing the total to 282.\tSix new Krispy Kreme stores were opened in the first quarter, bringing the total number of stores to 282.\n',
#  '3.600\tMs Lafferty\'s lawyer, Thomas Ezzell, told a Kentucky newspaper: "My understanding of this is that there is a lower percentage of successful impregnations with frozen.\t"My understanding of this is that there is a lower percentage of successful impregnations with frozen," Ezzell said.\n',
#  '5.000\tThe Federal Trade Commission (FTC) asked Congress today for additional authority to fight unwanted Internet spam, which now accounts for up to half of all e-mail traffic.\tThe Federal Trade Commission asked Congress yesterday for broader powers to attack the rapidly growing problem of spam, which new studies show accounts for half of all e-mail traffic.\n',
#  '3.400\tA federal grand jury indicted them on Tuesday; the document was sealed until yesterday to allow authorities to make arrests.\tFederal officials said the document remained sealed until Thursday morning to allow authorities to make arrests in five Western states.\n',
#  '4.000\tPeople who have opposed these actions throughout are now trying to find fresh reasons to say this wasn\'t the right thing to do."\t"What is happening here is that people who have opposed this action throughout are trying to find fresh reasons why it was not the right thing to do."\n',
#  '4.000\tKlarman was arrested by FBI agents in the Hamptons, an exclusive summer resort enclave east of New York City.\tKlarman was arrested by FBI agents Monday morning at his home in New York.\n',
#  "3.500\tThe bishop told police he thought he had hit a dog or a cat or that someone had thrown a rock at his vehicle.\tBishop O'Brien, aged 67, had told police he thought he had hit a dog or cat.\n",
#  '4.500\tThe report also claims that there will be up to 9.3 million visitors to hot spots this year, up again from the meagre 2.5 million in 2002.\tThere will be 9.3 million visitors to hot spots in 2003, up from 2.5 million in 2002, Gartner said.\n',
#  '3.200\tRichard Miller remained hospitalized after undergoing a liver transplant, but his wife has recovered.\tRichard Miller, 57, survived a lifesaving liver transplant but remains hospitalized.\n',
#  '3.800\tSequent representatives could not immediately be reached for comment on the SCO announcement.\tA spokesman for SCO could not be reached for comment this afternoon.\n',
#  '3.200\tThe proportion of people covered by employers dropped from 62.3 percent in 2001 to 61.3 percent last year.\tThe proportion of Americans with insurance from employers declined to 61.3 percent, from 62.6 percent in 2001 and 63.6 percent in 2000.\n',
#  '4.000\tWORLD No. 2 Lleyton Hewitt has accused the Association of Tennis Professionals of malice, including an alleged attempt last year to dupe him into refusing a drug test.\tWorld No.2 Lleyton Hewitt has accused his professional peers of long-standing malice, including an attempt last year to dupe him into refusing a drug test.\n',
#  '3.250\tMSN Messenger 6 will be available for download starting at 6 p.m. GMT on Wednesday from http://messenger.msn.com/download/v6preview.asp.\tThe MSN Messenger 6 software will be available from 11 a.m. PST on Wednesday, according to Microsoft.\n',
#  '3.000\tFamilies stuck on the highway remained in their cars, and used their cell phones to call home.\tFamilies stuck on the highway were being urged to remain in their cars, and to use their cell phones only in case of emergency.\n',
#  '4.250\tIn connection with the incident, I have acknowledged that I behaved inappropriately."\t"I have acknowledged that I behaved inappropriately," he said.\n',
#  '1.500\tA promotional poster, complete with countdown dial, reminds readers of the upcoming release of "Harry Potter and the Order of the Phoenix."\tThe crates are full of hardback copies of "Harry Potter and the Order of the Phoenix."\n',
#  '4.250\tA spokesman said: "Since November, we have co-operated fully with the police.\tIt added it had "co-operated fully" with police since November.\n',
#  '4.250\tWomen who eat potatoes and other tuberous vegetables during pregnancy may be at risk of triggering type 1 diabetes in their children, Melbourne researchers believe.\tAustralian researchers believe they have found a trigger of type 1 diabetes in children - their mothers eating potatoes and other tuberous vegetables during pregnancy.\n',
#  "0.750\tThe broad Standard & Poor's 500 Index .SPX inched up 3 points, or 0.32 percent, to 970.\tThe technology-laced Nasdaq Composite Index .IXIC lost 2 points, or 0.18 percent, to 1,649.\n",
#  '3.000\tPeople who once thought their blood pressure was fine actually may be well on their way to hypertension under new U.S. guidelines published on Wednesday.\tPeople who once thought their blood pressure was fine actually need to start exercising and eating better, according to new U.S. guidelines published on Wednesday.\n',
#  '3.500\t"Further testing is still under way, but at this stage, given the early detection, the outlook in such instances would be positive," the specialist said yesterday.\t"But at this stage, given the early detection, the outlook in such instances would be positive," he said.\n',
#  "3.750\tAmazon also reported that the New York Attorney General's office had settled civil fraud charges with one of the spoofers it identified.\tAmazon and the New York attorney general's office have already settled with one of the alleged e-mail forgers.\n",
#  "4.000\tThe leading actress nod went to energetic newcomer Marissa Jaret Winokur as Edna's daughter Tracy.\tMarissa Jaret Winokur, as Tracy, won for best actress in a musical.\n",
#  '1.750\tIn morning trading, the Dow Jones industrial average was up 40.12, or 0.5 percent, at 8,571.69, having fallen 51 points Monday.\tIn New York, the Dow Jones industrial average a gauge of 30 blue chip stocks was up 3.29 points or 0.04 per cent to 8,585.97.\n',
#  '1.750\tFor the entire season, the average five-day forecast track error was 259 miles, Franklin said.\t"The average track error for the five-day (forecast) is 323 nautical miles.\n',
#  '3.750\tRich media doubled its share, increasing from 3% in Q2 2002 to 6% in Q2 2003.\tRich Media interactive ad formats doubled their share from 3% in second quarter of 2002, to 6% in the second quarter of 2003.\n',
#  '4.000\t"It appears from our initial report that this was a textbook landing considering the circumstances," Burke said.\tSaid Mr. Burke: "It was a textbook landing considering the circumstances."\n',
#  "2.000\tAllegiant shares rose $4, or $17.2 percent, to $27.43 in Thursday morning trading on the Nasdaq Stock Market.\tAllegiant's stock closed Wednesday at $23.40, up 64 cents, in trading on the Nasdaq market.\n",
#  '3.400\tBy state law, 911 calls are not public information and were not released.\tBy law, 911 calls are not public information in Rhode Island.\n',
#  "1.400\tThe ADRs fell 10 cents to $28.95 at 10:06 a.m. in New York Stock Exchange composite trading today.\tShares of Fox Entertainment Group Inc., News Corp.'s U.S. media and entertainment arm, fell 45 cents to $26.85 in New York Stock Exchange composite trading.\n",
#  "4.800\tIt will take time to oust die-hard remnants of Saddam Hussein's deposed regime in Iraq, Defense Secretary Donald H. Rumsfeld said Tuesday.\tDefense Secretary Donald H. Rumsfeld said Tuesday it will take time to locate die-hard remnants of Saddam Hussein's deposed regime in Iraq.\n",
#  '2.000\tOrange shares jumped as much as 15 percent.\tFrance Telecom shares dropped 3.6 percent while Orange surged 13 percent.\n',
#  '3.400\tBremer said one initiative is to launch a $70 million nationwide program in the next two weeks to clean up neighborhoods and build community projects.\tBremer said he would launch a $70-million program in the next two weeks to clean up neighborhoods across Iraq and build community projects, but gave no details.\n',
# ...
#  '3.400\tSliding down the ice, Moriarty and Carella hit the spongy, rocky floor of the river and immediately felt the pull.\tSliding down the embankment, the two rescuers hit the spongy, rocky floor of the river and immediately felt the pull.\n',
#  '3.200\tCadbury Schweppes plc plans to cut 5500 jobs and shut factories after a 4.9 billion ($A11.9 billion) acquisition spree over the past three years inflated costs.\tCadbury Schweppes has unveiled plans to slash 5,500 jobs and 20 percent of its factories over four years to cut costs brought about by an acquisition spree.\n',
#  '3.500\tMr. Sweeney outlined plans for the campaign in a speech last night in Philadelphia at the annual meeting of the American Political Science Association.\tSweeney was to outline plans for the campaign in a speech on Saturday night at the annual meeting of the American Political Science Association.\n',
#  '3.750\tIt seemed like an isolated incident," said Ariel Dean of Washington D.C., who earned a degree in political science.\tIt seemed like an isolated incident,\'\' said graduate Ariel Dean of Washington, D.C.\n',
#  '1.750\tThe jury awarded TVT about $23 million in compensatory damages and roughly $108 million in punitive damages.\tTVT Records sought $360 million in punitive damages and $30 million in compensatory damages, officials said.\n',
#  '1.250\tTVT Records sought $360 million in punitive damages and $30 million in compensatory damages, officials said.\tThe damages included $24 million in compensatory damages and $52 million in punitive damages for IDJ.\n',
#  "3.400\tThe two Democrats on the five-member FCC panel held a news conference to sway opinion against Powell.\tThe two Democrats on the five-member FCC held a news conference to sway opinion against Powell and the panel's two other Republicans.\n",
#  '1.200\tUnit volumes also set a record as notebooks accounted for more than 40 percent of sales.\tIn May 2002, LCDs accounted for only 22 percent of monitor sales.\n',
#  '3.800\tBesides battling its sales slump, Siebel also has been sparring with some investors upset about huge stock option windfalls company managers have pocketed.\tBesides a sales slump, Siebel is sparring with some shareholders over management stock option windfalls.\n',
#  '3.200\tThat compared with a year-earlier profit of $102 million, or 13 cents a share.\tThat was more than double the $102 million, or 13 cents a share, for the year-earlier quarter.\n',
#  '3.500\tStanford (51-17) and Rice (57-12) will play for the national championship tonight.\tRice (57-12) and Stanford (51-17) will meet in a winner-take-all matchup at 6:05 p.m. Monday.\n',
#  '4.750\t"The economy, nonetheless, has yet to exhibit sustainable growth.\tBut the economy hasn\'t shown signs of sustainable growth.\n',
#  '3.500\tA 32-count indictment "strikes at one of the very top targets in the drug trafficking world," U.S. Attorney Marcos Jimenez said.\tThe newly unsealed 32-count indictment alleges money laundering and conspiracy and "strikes at one of the very top targets in the drug-trafficking world," Jiménez said.\n',
#  '2.000\tA soldier was killed Monday and another wounded when their convoy was ambushed in northern Iraq.\tOn Sunday, a U.S. soldier was killed and another injured when a munitions dump they were guarding exploded in southern Iraq.\n',
#  "2.800\tThe commission estimated California lost $937 million to corporate tax shelters in 2001.\tCalifornia's lost tax revenue was mostly due to international corporate tax shelters.\n",
#  '1.400\tIn other markets, U.S. Treasuries started off on Monday weaker, as stocks rose early.\tIn other markets, U.S. Treasuries inched higher as declining stocks raised the appeal of safe-haven debt.\n',
#  '2.000\tA cost analysis is under way, said Michael Rebell, CFE\'s executive director.\t"We\'re not looking for a Robin Hood remedy," said Michael Rebell, the campaign\'s executive director.\n',
#  '4.800\tI was going to the court believing I could do this, only if I played my best tennis.\t"I was believing that I was confident I could do this, but only in the case I would play my best tennis.\n',
#  '3.800\tDotson told FBI agents that he shot Dennehy after the player tried to shoot him, according to the arrest warrant affidavit.\tDotson was arrested July 21 after telling FBI agents he shot Dennehy when Dennehy tried to shoot him, according to the arrest warrant affidavit.\n',
#  '4.600\tDogs, he said, are second only to humans in the thoroughness of medical understanding and research.\tHe said that dogs are second only to humans in terms of being the subject of medical research.\n',
#  '1.400\tThe stock rose $2.11, or about 11 percent, to close on Friday at $21.51 on the New York Stock Exchange.\tPG&E Corp. shares jumped $1.63 or 8 percent to $21.03 on the New York Stock Exchange on Friday.\n',
#  '3.600\tEric Gagne earned his 17th save in as many opportunities as he struck out three in the ninth and allowed only an infield single by Greg Norton.\tCloser Eric Gagne earned his 17th save in as many opportunities as he struck out three of the four batters he faced in the ninth.\n',
#  "3.000\tBlair's government included the charge that Saddam sought uranium from Niger in a September 2002 dossier setting out the case for military action.\tBritain included the accusation in a September 2002 dossier setting out the case for war in Iraq.\n",
#  '1.600\tNot counting energy prices, wholesale prices were down 0.9 percent.\tEnergy prices dropped by 8.6 percent, the biggest decline since July 1986.\n',
#  '4.000\tThe spacecraft is scheduled to blast off as early as tomorrow or as late as Friday from the Jiuquan launching site in the Gobi Desert.\tThe spacecraft is scheduled to blast off between next Wednesday and Friday from a launching site in the Gobi Desert.\n',
#  '2.400\tHong Kong was flat, Australia , Singapore and South Korea lost 0.2-0.4 percent.\tAustralia was flat, Singapore was down 0.3 percent by midday and South Korea added 0.2 percent.\n',
#  '3.500\tSUVs parked on residential streets in Monrovia were tagged with "ELF" and other slogans, and another was set ablaze in front of a house, Sgt. Tom Wright said.\tSeveral SUVs parked on residential streets in Monrovia were tagged with ``ELF\'\' and other slogans, said Sgt. Tom Wright.\n',
#  "0.750\tThe technology-laced Nasdaq Composite Index .IXIC was down 25.36 points, or 1.53 percent, at 1,628.26.\tThe broader Standard & Poor's 500 Index .SPX gave up 11.91 points, or 1.19 percent, at 986.60.\n",
#  '5.000\tAt least 11 more cases in Indiana and three in Illinois are suspected.\tThere’s also at least three suspected cases in Illinois and 11 in Indiana.\n',
#  '5.000\tThe pill, which they call the "polypill," would contain aspirin, a cholesterol-lowering drug, three blood pressure-lowering drugs at half the standard dose and folic acid.\tThe ingredients of such a polypill would contain aspirin, a cholesterol-lowering statin, three blood pressure-lowering agents in half dose, and folic acid.\n',
#  '4.000\t"They drive around in their cars, while people are being killed 500 metres away," he said on Sunday.\t"What they are doing right now is they drive around in their cars, while people are being killed 500 metres away.\n',
#  "3.000\tAt Tuesday's arraignment hearing, Marsh pleaded not guilty to 122 counts of burial service fraud and 47 counts of making false statements.\tAt the hearing he pleaded not guilty to the burial service fraud and false statements charges.\n",
#  '1.333\tStill, revenues from the extra premiums would not be huge.\tHow would the extra premiums be collected?\n',
#  '3.667\tThe Pentagon had hoped to retain control of the postwar effort, so the decision is a victory for Secretary of State Colin L. Powell.\tThe Pentagon had hoped to retain control of the postwar effort, so the decision was seen by some insiders as a victory for Powell and the State Department.\n',
#  "3.091\tAiken's study appears in the Sept. 24 issue of the Journal of the American Medical Association.\tThe findings appear in Wednesday's Journal of the American Medical Association.\n",
#  "3.800\tSemiconductor giant Intel Corp. said yesterday that its second-quarter profits doubled from a year ago as stronger-than-expected demand for computer microprocessors offset the weakness of its communications chip business.\tIntel Corp.'s second-quarter profits doubled and revenues grew 8 percent from a year ago as the chip-making giant reported stronger-than-expected demand for personal computer microprocessors.\n",
#  '4.400\tA Merrill Lynch spokesman said "we are pleased with the judge\'s decision."\t"We are very pleased with the judge\'s decision," Merrill said yesterday.\n',
#  '4.800\tTrans fats are created when hydrogen is added to vegetable oil, solidifying it and increasing the shelf life of certain food products.\tTrans fats are created when vegetable oil has been partially hydrogenated, solidifying it and increasing the shelf life of certain products.\n',
#  "3.000\tSchroeder cancelled his Italian holiday after Stefani refused to apologise for the slurs, which came after Berlusconi compared a German politician to a Nazi concentration camp guard.\tStefani's remarks further stoked tension after Italian Prime Minister Silvio Berlusconi last week compared a German member of the European Parliament to a Nazi concentration camp guard.\n",
#  '2.667\tDell\'s OpenManage software includes Dell Update Packages with SMS to help automate the management of server hardware, applications and operating systems patches with a single tool.\tThe update packages help "automate the management of server hardware, applications and operating systems patches using one tool," which is unpleasantly vague.\n',
#  '4.000\tHe\'ll be swept over any minute or just die of the cold, Moriarty thought.\tFrom the top of the embankment, Moriarty thought, "He\'ll be swept over any minute or just die of the cold."\n',
#  "3.000\tLURD's Ja'neh also called for an interim government and the deployment of a U.S.-led Western peacekeeping force.\tThe rebels are also calling for the deployment of a U.S.-led peacekeeping force.\n",
#  '4.000\tKEDO Spokesman, Roland Tricot said: "The executive board decided to refer this question to capitals.\t"The executive board decided to refer this to the capitals," the Korean Energy Development Organization said.\n',
#  '5.000\tBut skeptics are concerned about the ease with which vendors can use these hardware-based security features to set digital rights management policies.\tBut skeptics are concerned about the ease at which these hardware-based security features could be used to set digital rights management policies by vendors.\n',
#  '3.400\tProf Sally Baldwin, 63, from York, fell into a cavity which opened up when the structure collapsed at Tiburtina station, Italian railway officials said.\tSally Baldwin, from York, was killed instantly when a walkway collapsed and she fell into the machinery at Tiburtina station.\n',
#  '3.400\tIt calls for the agency to plan an independent safety and engineering organization.\tThe agency has yet to fully formulate a strategy for the creation of an independent engineering technical authority.\n',
#  "3.857\tWorldCom's accounting problems came to light early last year, and the company filed for bankruptcy in July 2002, citing massive accounting irregularities.\tWorldCom's financial troubles came to light last year and the company subsequently filed for bankruptcy in July, 2002.\n",
#  '2.750\tBenchmark Treasury 10-year notes gained 17/32, yielding 4.015 percent.\tThe benchmark 10-year note was recently down 17/32, to yield 4.067 percent.\n',
#  "4.000\tProsecutors did an about-face in May and asked that the autopsy reports be unsealed after portions of Conner Peterson's autopsy report favorable to the defense were leaked to the media.\tThey asked that the autopsy reports be unsealed after portions of the autopsy report on Peterson's unborn son that were favorable to the defense were leaked to the media.\n",
#  '1.500\tVolume was moderate at 827.68 million shares, up from 798.95 million at the same point Tuesday.\tVolume came to 439.66 million shares, below 450.39 million at the same point Wednesday.\n',
#  "3.750\tPenn Traffic's stock closed at 36 cents per share on Wednesday on Nasdaq, up two cents.\tPenn Traffic stock closed Wednesday at 36 cents, up 2 cents, or 6.2 percent, from Tuesday's close.\n",
#  "2.750\tHotly contested legislation that would change the state's takeover law and help a Michigan-based development company fend off a takeover cleared the state Senate on Thursday.\tLegislation that would change state takeover law and help Bloomfield Hills-based Taubman Centers Inc. fend off a $1-billion takeover won committee approval Tuesday.\n",
#  '4.000\tHowever, other unions including the powerful CGT remained opposed to the reform and demanded the government begin fresh negotiations with them.\tThe powerful CGT and other unions remained opposed to the plans, however, and demanded the government renegotiate the reform with them.\n',
#  '1.500\tThe family owns Cheetahs strip clubs here and in Las Vegas.\tThe searches were conducted simultaneously with raids on strip clubs in San Diego and Las Vegas.\n',
#  '1.800\tThe new bill would have Medicare cover 95 percent of drug costs over $5,100.\tAbove that, seniors would be responsible for 100 percent of drug costs until the out-of-pocket total reaches $3,600.\n',
#  "4.000\tSeveral thousand 3rd Infantry troops, including the 3rd Brigade Combat Team based at Fort Benning in Columbus, began returning last week.\tA few thousand troops, most from the division's 3rd Brigade Combat Team based at Fort Benning in Columbus, began returning last week, with flights continuing through Friday.\n",
#  '3.000\tThe study also found that consumer goods advertisers continued to spend the most dollars online, representing 35% of all Web advertising.\tIn the second quarter, consumer advertisers continued to spend the most online, slightly increasing their share.\n',
#  '3.600\tPrairie dogs sold as exotic pets are believed to have been infected in an Illinois pet shop by a Gambian giant rat imported from Africa.\tPrairie dogs are believed to have become infected in a pet shop through a Gambian rat imported from Africa.\n',
#  "3.400\tThe defense cannot appeal Roush's ruling until after the trial.\tDefense lawyers cannot appeal the ruling until after trial, in the appellate courts.\n",
#  "3.000\tCrohn's disease causes inflammation of the intestine and symptoms include diarrhea, pain, weight loss and tiredness.\tSymptoms include chronic diarrhoea, abdominal pain, weight loss and extreme tiredness.\n",
#  '2.600\tThe committee was appointed by Defense Secretary Donald Rumsfeld under orders from Congress.\tThe public hearing is the second for the panel created by Defense Secretary Donald Rumsfeld under pressure from Congress.\n',
#  '3.200\tAuthorities identified the tipster as Richard Powell, who is imprisoned for killing his landlady in 1982.\tPowell is serving time in a different case -- killing his landlady in 1982.\n',
#  '3.500\tKiernan testified that Seifert had received a gunshot wound to the back.\tSeifert, he testified, had a gunshot wound in the back.\n',
#  '3.250\tFormer Indiana Rep. Frank McCloskey, 64, died Sunday in Bloomington after a battle with bladder cancer.\tMcCloskey died Sunday afternoon in his home after a year-long battle with bladder cancer.\n',
#  '3.750\tHospitals and the Red Cross appealed to blood donors yesterday.\tThe Connecticut Hospital Association joined the Red Cross Monday in calling for more blood donors.\n',
#  '3.250\tIt is priced at $5,995 for an unlimited number of users tapping into the single processor, or $195 per user with a minimum of five users.\tIt is priced at $5,995 or $195 on a per user licensing plan with a minimum of five users.\n']

# %% [markdown]
# # Separating Sentence 1, Sentence 2 and Score

# %%
df = []
for i in range(len(data)):
    df.append(data[i].split('\t'))
    
score = []
sentence1 = []
sentence2 = []
for j in range(len(df)):
    score.append(df[j][0])
    sentence1.append(df[j][1])
    b = df[j][2]
    sentence2.append(b.rstrip("\n"))

# %% [markdown]
# # Creating DataFrame with columns Sentence1, Sentence2, Score

# %%
dict = list(zip(sentence1, sentence2, score))
df = pd.DataFrame(dict, columns = ['Sentence1', 'Sentence2', 'Score'])

# %%
df.head()
# Out:
#                                            Sentence1  \
# 0  But other sources close to the sale said Viven...
# 1  Micron has declared its first quarterly profit...
# 2  The fines are part of failed Republican effort...
# 3  The American Anglican Council, which represent...
# 4  The tech-loaded Nasdaq composite rose 20.96 po...
#
#                                            Sentence2  Score
# 0  But other sources close to the sale said Viven...  4.000
# 1  Micron's numbers also marked the first quarter...  3.750
# 2  Perry said he backs the Senate's efforts, incl...  2.800
# 3  The American Anglican Council, which represent...  3.400
# 4  The technology-laced Nasdaq Composite Index <....  2.400

# %% [markdown]
# #  Calling web service using POST method with this request
# ### Model's
# * USE (Universal Sentence Encoder)
# * BERT (Bidirectional Encoder Representations from Transformers)

# %%
BERT_SimilarityScore = []
USE_SimilarityScore = []
use = []
bert = []

model = ["USE", "BERT"]
for y in model:
    url = 'http://192.168.0.199:5010/sentence_similarity?model='+y
    print(url)
    for i in range(len(df)):
        a = df.Sentence1[i].strip(",")
        b = df.Sentence2[i].strip(",")
        d = { "sentence1":"\'"+str([df.Sentence1[i].replace(",", "")])+"\'", "sentence2":"\'"+str([df.Sentence2[i].replace(",", "")])+"\'"}
        r = requests.post(url, data=d)
        if y == "USE":
            use.append(r.json())
        else:
            bert.append(r.json())
    
for u in range(len(use)):
    USE_SimilarityScore.append(float(use[u][0][0]["similarityScore"]))
    
for k in range(len(use)):
    BERT_SimilarityScore.append(float(bert[k][0][0]["smilarity_score"]))
# Out:
# http://192.168.0.199:5010/sentence_similarity?model=USE
# http://192.168.0.199:5010/sentence_similarity?model=BERT

# %% [markdown]
# ## Adding 2 new columns to the dataframe (USE_SimilarityScore & BERT_SimilarityScore) and also rescaling the Score column between 0 to 1

# %%
dic = list(zip(sentence1, sentence2, score, USE_SimilarityScore, BERT_SimilarityScore))
df = pd.DataFrame(dic, columns = ['Sentence1', 'Sentence2', 'Score', 'USE_SimilarityScore', 'BERT_SimilarityScore'])

scaler = MinMaxScaler()
df['Score'] = scaler.fit_transform(df['Score'].values.reshape(-1,1))

# %%
df.head()
# Out:
#                                            Sentence1  \
# 0  But other sources close to the sale said Viven...
# 1  Micron has declared its first quarterly profit...
# 2  The fines are part of failed Republican effort...
# 3  The American Anglican Council, which represent...
# 4  The tech-loaded Nasdaq composite rose 20.96 po...
#
#                                            Sentence2     Score  \
# 0  But other sources close to the sale said Viven...  0.789474
# 1  Micron's numbers also marked the first quarter...  0.736842
# 2  Perry said he backs the Senate's efforts, incl...  0.536842
# 3  The American Anglican Council, which represent...  0.663158
# 4  The technology-laced Nasdaq Composite Index <....  0.452632
#
#    USE_SimilarityScore  BERT_SimilarityScore
# 0             0.960873              0.978246
# 1             0.718226              0.945510
# 2             0.785982              0.938160
# 3             0.846785              0.966029
# 4             0.871605              0.963640

# %% [markdown]
# # Computing the Pearson correlation between USE semantic similarity scores and human judgement Score.

# %%
pearson_coef, p_value = stats.pearsonr(df["Score"], df["USE_SimilarityScore"]) 
print("Pearson Correlation Coefficient: ", pearson_coef, "and a P-value of:", p_value)
# Out:
# Pearson Correlation Coefficient:  0.3751883142712514 and a P-value of: 1.756959208811763e-26

# %% [markdown]
# # Computing the Pearson correlation between BERT semantic similarity scores and human judgement Score.

# %%
pearson_coef, p_value = pearsonr(df["Score"], df["BERT_SimilarityScore"]) #define the columns to perform calculations on
print("Pearson Correlation Coefficient: ", pearson_coef, "and a P-value of:", p_value) # Results
# Out:
# Pearson Correlation Coefficient:  0.19917268476135105 and a P-value of: 3.783413102206333e-08

# %%
df.corr()
# Out:
#                          Score  USE_SimilarityScore  BERT_SimilarityScore
# Score                 1.000000             0.375188              0.199173
# USE_SimilarityScore   0.375188             1.000000              0.324532
# BERT_SimilarityScore  0.199173             0.324532              1.000000
